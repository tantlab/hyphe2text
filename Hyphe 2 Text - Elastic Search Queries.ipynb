# %%
## INITIALIZATION
# Install ElasticSearch pip package in current Jupyter kernel
import sys
# !{sys.executable} -m pip install elasticsearch

# Imports
import elasticsearch

# Settings - *** YOU MUST EDIT THEM! ***
settings = {
    'es_host': 'localhost',
    'es_port': '9200',
    'es_index': 'nordic-design',
}

# Init Elastic Search handler
es = elasticsearch.Elasticsearch([{'host': settings['es_host'], 'port': settings['es_port']}])
# Out:
# Requirement already satisfied: elasticsearch in c:\users\mj\appdata\local\continuum\anaconda3\lib\site-packages (6.3.1)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\mj\appdata\local\continuum\anaconda3\lib\site-packages (from elasticsearch) (1.23)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# EXAMPLE QUERY 1: All web entities
es.search(
    index=settings['es_index'],
    body={
        "query": {
            "match": { "type": "webentity" }
        },
        "size": 3 # Limit to 3 for convenience
    }
)
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 254,
#   'max_score': 3.5556765,
#   'hits': [{'_index': 'nordic-design',
#     '_type': 'doc',
#     '_id': '124',
#     '_score': 3.5556765,
#     '_source': {'status': 'IN',
#      'type': 'webentity',
#      'name': 'Hankjobenhavn.com',
#      'crawling_status': 'FINISHED',
#      'indegree': 4,
#      'tags': {'CORE-STARTPAGES': {'user': ['http://hankjobenhavn.com']},
#       'USER': {'Country': ['Denmark'], 'Branch': ['Company']},
#       'CORE': {'createdBy': ['user via lru']}},
#      'startpages': ['http://hankjobenhavn.com'],
#      'creation_date': 1539159539130,
#      'prefixes': ['s:http|h:com|h:hankjobenhavn|h:www|',
#       's:http|h:com|h:hankjobenhavn|',
#       's:https|h:com|h:hankjobenhavn|',
#       's:https|h:com|h:hankjobenhavn|h:www|'],
#      'indexing_status': 'FINISHED',
#      'crawled': True,
#      'last_modification_date': 1539423166133,
#      'homepage': 'http://www.hankjobenhavn.com',
#      'id': 124}},
#    {'_index': 'nordic-design',
#     '_type': 'doc',
#     '_id': '231',
#     '_score': 3.5556765,
#     '_source': {'status': 'IN',
#      'type': 'webentity',
#      'name': 'Skagerak.dk',
#      'crawling_status': 'FINISHED',
#      'indegree': 2,
#      'tags': {'CORE-STARTPAGES': {'user': ['http://skagerak.dk']},
#       'USER': {'Country': ['Denmark'], 'Branch': ['Company']},
#       'CORE': {'createdBy': ['user via lru']}},
#      'startpages': ['http://skagerak.dk'],
#      'creation_date': 1539159541360,
#      'prefixes': ['s:https|h:dk|h:skagerak|',
#       's:http|h:dk|h:skagerak|h:www|',
#       's:http|h:dk|h:skagerak|',
#       's:https|h:dk|h:skagerak|h:www|'],
#      'indexing_status': 'FINISHED',
#      'crawled': True,
#      'last_modification_date': 1539423178103,
#      'homepage': 'https://www.skagerak.dk/dk/',
#      'id': 231}},
#    {'_index': 'nordic-design',
#     '_type': 'doc',
#     '_id': '261',
#     '_score': 3.5556765,
#     '_source': {'status': 'IN',
#      'type': 'webentity',
#      'name': 'Urgent.agency',
#      'crawling_status': 'FINISHED',
#      'indegree': 3,
#      'tags': {'CORE-STARTPAGES': {'user': ['http://urgent.agency']},
#       'USER': {'Country': ['Denmark'], 'Branch': ['Company']},
#       'CORE': {'createdBy': ['user via lru']}},
#      'startpages': ['http://urgent.agency'],
#      'creation_date': 1539159542076,
#      'prefixes': ['s:https|h:agency|h:urgent|',
#       's:https|h:agency|h:urgent|h:www|',
#       's:http|h:agency|h:urgent|',
#       's:http|h:agency|h:urgent|h:www|'],
#      'indexing_status': 'FINISHED',
#      'crawled': True,
#      'last_modification_date': 1539423180491,
#      'homepage': 'http://urgent.agency',
#      'id': 261}}]}}

# %%
# EXAMPLE QUERY 2: All pages containing a given expression
search_query = "funny"
es.search(
    index=settings['es_index'],
    body={
        "query": {
            "bool": {
              "must": [
                { "match": { "type": "page" } },
                { "match": { "text": search_query } }
              ]
            }
        },
        "size": 3 # Limit to 3 for convenience
    }
)
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 5,
#   'max_score': 7.265485,
#   'hits': [{'_index': 'nordic-design',
#     '_type': 'doc',
#     '_id': 's:https|h:se|h:nola|p:products|p:organic|p:|',
#     '_score': 7.265485,
#     '_source': {'status': 200,
#      'webentity_status': 'IN',
#      'encoding': 'utf-8',
#      'url': 'https://nola.se/products/organic/',
#      'timestamp': 1539425542809,
#      'forgotten': False,
#      'text': 'Som ett komplement till vårt eget sortiment marknadsför vi produkter från italienska\xa0Bellitalia, som liksom Nola arbetar för god\xa0design i det offentliga uterummet. Bellitalia är verksamma inom street och urban landscaping och utmärker sig med organiska former och spännande material såsom\xa0betong, marmor och polyuretan. Produkterna signalerar kvalitet, funktionalitet och\xa0innovativ\xa0design. Möbler utformade för att passa in i\xa0den levande staden. Serien Organic, design\xa0Matouš Holý, är utformad\xa0efter tanken\xa0om den levande staden. Möblerna är anpassade för att på ett\xa0dynamiskt sätt passa in i den urbana miljöns\xa0olika arkitektoniska delar. Tillverkade i betong och sprutade med\xa0polyuretan som\xa0sedan lackeras\xa0är de\xa0slitstarka och tåliga och har en lång livslängd.\xa0Organic finns\xa0i olika former och utföranden i färgerna\xa0röd, svart eller vit samt i vit granit. Serien består av\xa0Harmony, Cuddly och Family som stol/bord/sittmöbel och Happy och Funny som bänk/sittmöbel. De olika delarna går utmärkt att kombinera med varandra.',
#      'depth': 1,
#      'webentity': 205,
#      'webentity_name': 'Nola.se',
#      'lrulinks': ['s:https|h:se|h:nola|p:product|p:spaljeer|p:|',
#       's:https|h:se|h:nola|p:product|p:papperskorgar|p:|',
#       's:https|h:se|h:nola|p:product|p:inventarrum|p:|',
#       's:https|h:se|h:nola|p:product|p:pollare|p:|',
#       's:https|h:com|h:facebook|h:www|p:NolaPublicDesign|',
#       's:https|h:se|h:nola|p:product|p:bord|p:|',
#       's:https|h:se|h:nola|p:kontakt|p:|',
#       's:https|h:se|h:nola|p:product|p:jan-kuipers-nunspeet|p:|',
#       's:https|h:se|h:nola|p:product|p:nyheter|p:|',
#       's:https|h:se|h:nola|p:sparade-produkter|p:|',
#       's:https|h:se|h:nola|p:product|p:tradskydd|p:|',
#       's:https|h:se|h:nola|p:product|p:kallsortering|p:|',
#       's:https|h:se|h:nola|p:trycksaker|p:|',
#       's:https|h:se|h:nola|p:product|p:planteringskarl|p:|',
#       's:https|h:se|h:uc|h:www|p:risksigill|',
#       's:https|h:se|h:nola|p:press|p:|',
#       's:https|h:se|h:nola|p:product|p:staket|p:|',
#       's:https|h:se|h:nola|p:product|p:ovriga-varumarken|p:|',
#       's:https|h:se|h:nola|p:utmarkelser|p:|',
#       's:https|h:se|h:nola|p:products|p:|',
#       's:http|h:net|h:bellitalia|h:www|p:en|p:|',
#       's:https|h:se|h:nola|p:products|p:organic|p:|',
#       's:https|h:com|h:instagram|h:www|p:nola_design_furniture|',
#       's:https|h:se|h:nola|p:products|p:demetra-bank|p:|',
#       's:https|h:se|h:nola|p:wp-content|p:plugins|p:nola-functionality|p:core|p:zipimages.php|q:post=32707|',
#       's:https|h:se|h:nola|p:wp-content|p:plugins|p:nola-functionality|p:core|p:zipimages.php|q:post=32707&img=4|',
#       's:https|h:se|h:nola|h:cdn|p:wp-content|p:uploads|p:ORGANIC-SET-3.jpg|',
#       's:https|h:se|h:nola|p:product|p:stockholm-furniture-fair-2018|p:|',
#       's:https|h:se|h:nola|p:products|p:luna|p:|',
#       's:https|h:se|h:nola|',
#       's:https|h:se|h:nola|p:products|p:jonathan-bank|p:|',
#       's:https|h:se|h:nola|p:product|p:rumsavdelare|p:|',
#       's:https|h:se|h:nola|p:product|p:avgransning|p:|',
#       's:https|h:se|h:nola|p:products|p:family|p:|',
#       's:https|h:se|h:nola|p:products|p:marte-planteringskarl|p:|',
#       's:https|h:se|h:nola|p:product|p:jessing|p:|',
#       's:https|h:se|h:nola|p:designers|p:|',
#       's:https|h:se|h:nola|p:products|p:onda-bank|p:|',
#       's:https|h:se|h:nola|p:material-och-miljo|p:|',
#       's:https|h:com|h:bimobject|p:embed|p:nola|p:privatecloud|p:nola|',
#       's:https|h:se|h:nola|p:products|p:cuddly|p:|',
#       's:https|h:se|h:nola|h:cdn|p:wp-content|p:uploads|p:ORGANIC-SET-2.jpg|',
#       's:https|h:se|h:nola|p:foretagsfakta|p:|',
#       's:https|h:se|h:nola|p:personal|p:|',
#       's:https|h:se|h:nola|p:product|p:special|p:|',
#       's:https|h:se|h:nola|p:products|p:happy|p:|',
#       's:https|h:se|h:nola|p:product|p:plantering|p:|',
#       's:https|h:se|h:nola|p:product|p:bellitalia|p:|',
#       's:https|h:se|h:nola|p:product|p:mobelgrupper|p:|',
#       's:https|h:se|h:nola|p:en|p:|',
#       's:https|h:se|h:nola|h:cdn|p:wp-content|p:uploads|p:ORGANIC-SET-7.jpg|',
#       's:https|h:se|h:nola|p:product|p:pergola|p:|',
#       's:https|h:se|h:nola|p:product|p:mobler|p:|',
#       's:https|h:se|h:nola|p:product|p:modulsystem-2|p:|',
#       's:https|h:se|h:nola|h:cdn|p:wp-content|p:uploads|p:ORGANIC-1.jpg|',
#       's:https|h:se|h:nola|p:product|p:cykelstall|p:|',
#       's:https|h:se|h:nola|p:kundtjanst|p:|',
#       's:https|h:se|h:nola|p:product|p:stolar-fatoljer|p:|',
#       's:https|h:se|h:nola|p:product|p:renhallning|p:|',
#       's:https|h:se|h:nola|h:cdn|p:wp-content|p:uploads|p:ORGANIC-belitalia.jpg|',
#       's:https|h:se|h:nola|p:product|p:bankar|p:|',
#       's:https|h:se|h:nola|p:products|p:organic|p:|q:tab=images|',
#       's:https|h:se|h:nola|p:product|p:cykelpollare|p:|',
#       's:https|h:se|h:nola|p:product|p:skarmarforvaring|p:|',
#       's:https|h:se|h:nola|p:product|p:cykelmiljo|p:|',
#       's:https|h:se|h:nola|p:product|p:vaderskydd|p:|',
#       's:https|h:se|h:nola|p:products|p:gea-stol|p:|',
#       's:http|h:se|h:nola|h:www|',
#       's:https|h:se|h:nola|p:wp-content|p:plugins|p:nola-functionality|p:core|p:zipimages.php|q:post=32707&img=5|',
#       's:https|h:se|h:nola|p:product|p:nordfjell-collection|p:|',
#       's:https|h:se|h:nola|p:wp-content|p:plugins|p:nola-functionality|p:core|p:zipimages.php|q:post=32707&img=1|',
#       's:https|h:se|h:nola|p:wp-content|p:plugins|p:nola-functionality|p:core|p:zipimages.php|q:post=32707&img=0|',
#       's:https|h:se|h:nola|p:wp-content|p:plugins|p:nola-functionality|p:core|p:zipimages.php|q:post=32707&img=3|',
#       's:https|h:se|h:nola|p:wp-content|p:plugins|p:nola-functionality|p:core|p:zipimages.php|q:post=32707&img=2|',
#       's:https|h:se|h:nola|p:product|p:sittmobler|p:|',
#       's:https|h:com|h:pinterest|h:se|p:nola0141|p:|',
#       's:https|h:se|h:nola|p:products|p:alba-bank-aurora-bord|p:|',
#       's:http|h:se|h:soliditet|h:www|p:lang|p:sv_SE|p:RatingGuideline|',
#       's:https|h:se|h:nola|p:product|p:grijsen|p:|',
#       's:https|h:se|h:nola|h:cdn|p:wp-content|p:uploads|p:Material-och-underh%C3%A5ll_Nola.pdf|',
#       's:https|h:se|h:nola|p:cookies|p:|',
#       's:https|h:se|h:nola|p:skotselrad|p:|',
#       's:https|h:se|h:nola|p:products|p:olimpo-bank-och-planteringskarl|p:|',
#       's:https|h:se|h:nola|p:product|p:ovrigt-cykel|p:|',
#       's:https|h:se|h:nola|p:products|p:harmony|p:|',
#       's:https|h:se|h:nola|h:cdn|p:wp-content|p:uploads|p:nola-personuppgiftspolicy.pdf|',
#       's:https|h:se|h:nola|p:products|p:organic|p:|q:tab|',
#       's:https|h:se|h:nola|p:product|p:up-serien|p:|',
#       's:https|h:se|h:nola|p:product|p:inframarks|p:|',
#       's:https|h:se|h:nola|p:products|p:fanny|p:|',
#       's:https|h:se|h:nola|p:%C3%A5terf%C3%B6rs%C3%A4ljare|p:|',
#       's:https|h:se|h:nola|h:cdn|p:wp-content|p:uploads|p:ORGANIC-2.jpg|',
#       's:https|h:se|h:nola|p:product|p:cykeltak|p:|',
#       's:https|h:se|h:nola|p:product|p:askkopp|p:|',
#       's:https|h:se|h:nola|p:references|p:|',
#       's:https|h:se|h:nola|p:product|p:parksoffor|p:|',
#       's:https|h:se|h:nola|p:product|p:specialprodukter|p:|'],
#      'lru': 's:https|h:se|h:nola|p:products|p:organic|p:|',
#      'content_type': 'text/html',
#      'error': None,
#      '_job': 'a3e88dd9cecf11e8a4230242ac120003',
#      'type': 'page',
#      'size': 46184}},
#    {'_index': 'nordic-design',
#     '_type': 'doc',
#     '_id': 's:http|h:com|h:fargblanche|p:EMMA-for-GARSNAS|',
#     '_score': 6.2603803,
#     '_source': {'status': 200,
#      'webentity_status': 'IN',
#      'encoding': 'utf-8',
#      'url': 'http://fargblanche.com/EMMA-for-GARSNAS',
#      'timestamp': 1539423798715,
#      'forgotten': False,
#      'text': 'What made it an Emma?EMB/FF: Gärsnäs asked us to design a modern Emma armchair, and we had a really exciting time doing it! You get such a kick out of working towards a solution and, what’s more, spotting a need. And the Emma just came naturally, this being a latter-day version of a firmly rooted tradition.Had this kind of seating furniture occurred to you previously?EMB: The funny thing is that, despite being French, I’ve always had a special relationship to Emma armchairs. I was already keen on design as a child, and my Swedish paternal grandmother had an Emma armchair which I just couldn’t take my eyes off. Later on, when I inherited that chair, I felt both honoured and overjoyed.What’s so special about your Emma?FF: It’s a hand-sewn, well-tailored armchair that speaks the language of craftsmanship picking up the gauntlet. The needlework here involves both form and function, elevating the classic look to a superior level. Both the seams and the stockinged legs accentuate that “well-dressed” feeling.',
#      'depth': 1,
#      'webentity': 99,
#      'webentity_name': 'Fargblanche.com',
#      'lrulinks': ['s:http|h:com|h:fargblanche|h:www|p:filter|p:furniture|',
#       's:http|h:com|h:fargblanche|p:Succession-Mirrors|',
#       's:http|h:com|h:fargblanche|p:SKYSCRAPE|',
#       's:http|h:com|h:fargblanche|p:CONTACT|',
#       's:http|h:com|h:fargblanche|p:NEWS|',
#       's:http|h:com|h:fargblanche|p:LINE|',
#       's:http|h:com|h:fargblanche|p:INSIDE-SCANDINAVIAN-DESIGN-exhibition|',
#       's:http|h:com|h:fargblanche|p:JULIUS-Sofa-GARSNAS|',
#       's:http|h:com|h:fargblanche|p:F-A-B-CHAIR-couture|',
#       's:http|h:com|h:fargblanche|p:COUTURE-armchair-produced-by-B-D-BARCELONA-DESIGN|',
#       's:http|h:com|h:fargblanche|p:EMILY-for-GARSNAS|',
#       's:http|h:com|h:fargblanche|p:KILT|',
#       's:http|h:com|h:fargblanche|p:SUCCESSION-CERAMIC-Petite-Friture|',
#       's:http|h:com|h:fargblanche|p:F-A-B-chair|',
#       's:http|h:com|h:fargblanche|p:20-DESIGNERS-AT-BIOLOGISKA|',
#       's:http|h:com|h:fargblanche|p:Pocket-Cupboard-WOOD-TAILORING|',
#       's:http|h:com|h:fargblanche|p:METAL-STICHING|',
#       's:http|h:com|h:fargblanche|p:LOUD-for-NORTHERN|',
#       's:http|h:com|h:fargblanche|p:FOLDER|',
#       's:http|h:com|h:fargblanche|p:Art-Film-LONGING-TO-FLY-LONGING-TO-FALL|',
#       's:http|h:com|h:fargblanche|p:BEYOND-COUTURE|',
#       's:http|h:com|h:fargblanche|p:NORMA-for-JOHANSON|',
#       's:http|h:com|h:fargblanche|p:FRANKIE-JOHANSON-DESIGN|',
#       's:http|h:com|h:fargblanche|p:PRESS|',
#       's:http|h:com|h:fargblanche|p:FISKAREN-TINGEST|',
#       's:http|h:com|h:fargblanche|p:Layer-armchair-WOOD-TAILORING|',
#       's:https|h:com|h:instagram|h:www|p:fargblanche|p:|',
#       's:http|h:com|h:fargblanche|p:EMILY-swivel-GARSNAS|',
#       's:http|h:com|h:fargblanche|p:RHUBARB|',
#       's:http|h:com|h:fargblanche|p:Nailed-Succession|',
#       's:http|h:com|h:fargblanche|p:MODUS-COVER|',
#       's:http|h:com|h:fargblanche|p:MOON|',
#       's:http|h:com|h:fargblanche|p:EMMA-for-GARSNAS|',
#       's:http|h:com|h:fargblanche|p:COAT|',
#       's:http|h:com|h:fargblanche|p:FRANKIE-stool-JOHANSON-DESIGN|',
#       's:http|h:com|h:fargblanche|p:RING-TINGEST|',
#       's:http|h:com|h:fargblanche|p:COUTURE-cabinet-for-BD-BARCELONA|',
#       's:http|h:com|h:fargblanche|p:Wood-tailoring-accessories-bags|',
#       's:http|h:com|h:fargblanche|h:www|',
#       's:http|h:com|h:fargblanche|p:F-A-B-CHAIR-small-dress|',
#       's:http|h:com|h:fargblanche|p:Tapis-de-compagnie|',
#       's:http|h:com|h:fargblanche|p:SUCCESSION-lounge-chair|',
#       's:http|h:com|h:cargocollective|',
#       's:http|h:com|h:fargblanche|p:RE-COVER-black|',
#       's:http|h:com|h:fargblanche|p:Mr-N-for-GARSNAS|',
#       's:http|h:com|h:fargblanche|p:JULIUS-Armchair-GARSNAS|',
#       's:http|h:com|h:fargblanche|p:DESIGN-WALK|',
#       's:http|h:com|h:fargblanche|p:SUCCESSION-cabinet|',
#       's:http|h:com|h:fargblanche|p:SUCCESSION|',
#       's:http|h:com|h:fargblanche|p:ABOUT|',
#       's:http|h:com|h:fargblanche|p:Scott|',
#       's:http|h:com|h:fargblanche|p:Shelf-BRIDGE|',
#       's:http|h:com|h:fargblanche|p:SKEPPSKORG|',
#       's:http|h:com|h:fargblanche|p:RAM-DESIGH-HOUSE-STOCKHOLM|',
#       's:http|h:com|h:fargblanche|p:DARK-LAYER|',
#       's:http|h:com|h:fargblanche|p:MAJOR|',
#       's:http|h:com|h:fargblanche|p:Fly-F-A-B|',
#       's:http|h:com|h:fargblanche|p:Bespoke-chair-WOOD-TAILORING|',
#       's:http|h:com|h:fargblanche|p:Simple-Be-LIMITED|',
#       's:http|h:com|h:fargblanche|p:FRANKIE-lounge-JOHANSON-DESIGN|',
#       's:http|h:com|h:fargblanche|p:RE-COVER-red|',
#       's:http|h:com|h:fargblanche|p:ELSA-JACK-GARSNAS|',
#       's:http|h:com|h:fargblanche|p:ARMOUR-mon-AMOUR|',
#       's:http|h:com|h:fargblanche|p:ROCK-CHAIR|'],
#      'lru': 's:http|h:com|h:fargblanche|p:EMMA-for-GARSNAS|',
#      'content_type': 'text/html',
#      'error': None,
#      '_job': '616f08f5cecc11e8b04e0242ac120003',
#      'type': 'page',
#      'size': 67406}},
#    {'_index': 'nordic-design',
#     '_type': 'doc',
#     '_id': 's:https|h:com|h:kahoot|p:blog|p:2017|p:12|p:05|p:getty-images-case-study-kahoot|p:|',
#     '_score': 2.4768832,
#     '_source': {'status': 200,
#      'webentity_status': 'IN',
#      'encoding': 'utf-8',
#      'url': 'https://kahoot.com/blog/2017/12/05/getty-images-case-study-kahoot/',
#      'timestamp': 1539163193981,
#      'forgotten': False,
#      'text': '“I never thought you could make CRM training fun. I was wrong!” – said one of the sales leaders at Getty Images after a training session. Guess what made him change his mind?\n\nTraining 1,000+ sales managers in 25 offices with Kahoot!, their team cracked the code of turning training into something fun and impactful that participants really look forward to.\n\nIn this case study, Getty Images’ team reveal their secret of making training exciting and memorable and share how Kahoot! became part of their organizational culture. It’s based on a great chat we had with Greg McLaughlin (VP of global sales operations), Colleen Chardos (CRM product manager) and Michael Carrabba (training consultant) – real Kahoot! champions in the workplace!\n\nSlideshow on the screen, hands-on exercise, paper questionnaires after the session – this was the traditional setup for sales training at Getty Images for several years. Quite a solid model, but the sessions didn’t seem to spark as much excitement among participants as possible. The trainers, in their turn, had to analyze the questionnaires after every session and manually input that data into spreadsheets.\n\nToday, these challenges are long forgotten. Last year, training consultant Michael Carrabba, introduced his colleagues to Kahoot! According to Michael, the ease of use immediately bought everyone in, and, of course, the competition part – salespeople are known to be very competitive!\n\nBased on feedback of 1,000 sales trainees, a training session with Kahoot! is now rated 4.75-4.8 out of 5. Well played, Getty Images team!\n\nWe asked Greg, Michael and Colleen to tell us a bit more about their recent global sales training. In the course of three weeks, they trained 1,000+ sales managers in 25 offices (20 countries, five continents). Here’s what a typical training session looked like:\n\nEach session was divided into 45-minute modules: 15 min for instruction, 15 min for a hands-on learning exercise, then time for Q&A and, finally, a 3-5-minute kahoot in the end of every module. Participants knew in advance that there would be kahoots, so everyone was very motivated to follow the content, not missing any bit of info so that they had a chance to win!\n\nAfter the session, the winners enjoyed their moment of glory, taking photos in front of the screen with their name on the podium. Clearly, adults get in the competitive Kahoot! spirit just as much as school students!\n\nIn addition to the wildly energetic vibe that everyone enjoyed, Greg and Michael pointed out how Kahoot! helped them with the analytical aspect of training – tracking learning progress. No matter who ran the training session, they could access reports across all games in Kahoot! Plus. This data helps trainers plan the next session: for example, if some questions got a low share of correct answers, they might revise the training program and make sure to emphasize that content a bit more.\n\nKahoot! is now used in many different scenarios at Getty Images: service and CRM training, presentations, management meetings, project catch-ups, and events (for example, Dreamforce conference earlier this year).\n\nAccording to Greg, who leads the Sales Learning and Development team, whenever training is organized it’s expected by default that there’s going to be a kahoot in it. This expectation shows that Kahoot! has become part of the organizational culture at Getty Images!\n\n1. Come up with credible incorrect answers\n\nIncorrect answer alternatives are part of the learning experience, too. Come up with relevant and credible ones and mix them up depending on the setting. For example, in the management meeting all four alternatives were serious, making questions tricky. In a regular training, a typical mix is 3 serious answers + 1 funny alternative giving everyone a laugh.\n\nSpeaking of laugh – a bit of humor makes a kahoot even more memorable. In the kahoot Colleen and Greg hosted at the Dreamforce conference, three altern ...
#      'depth': 1,
#      'webentity': 158,
#      'webentity_name': 'Kahoot.com',
#      'lrulinks': ['s:https|h:com|h:kahoot|p:|q:page_id=4364|',
#       's:https|h:com|h:kahoot|p:blog|p:author|p:daniella|p:|',
#       's:https|h:com|h:kahoot|p:schools|p:|',
#       's:https|h:com|h:kahoot|p:blog|p:tag|p:thought-leaders|p:|',
#       's:https|h:com|h:kahoot|p:blog|p:author|p:daria|p:|',
#       's:https|h:com|h:kahoot|h:shop|',
#       's:https|h:com|h:kahoot|p:blog|p:2018|p:09|p:13|p:formative-assessment-case-study-history-teacher|p:|',
#       's:https|h:com|h:kahoot|p:businesses|p:|',
#       's:https|h:it|h:kahoot|',
#       's:https|h:com|h:kahoot|p:press|p:|',
#       's:https|h:com|h:kahoot|p:explore-games|p:|',
#       's:https|h:com|h:facebook|h:www|p:sharer|p:sharer.php|q:u=https%3A%2F%2Fkahoot.com%2Fblog%2F2017%2F12%2F05%2Fgetty-images-case-study-kahoot%2F|',
#       's:https|h:com|h:kahoot|p:how-to-play-kahoot|p:|',
#       's:https|h:com|h:kahoot|p:certified|p:|',
#       's:https|h:com|h:kahoot|p:businesses|p:plus|p:|',
#       's:https|h:com|h:kahoot|p:blog|p:|',
#       's:https|h:com|h:kahoot|p:investor-relations|p:|',
#       's:https|h:com|h:kahoot|p:blog|p:2018|p:08|p:27|p:students-become-leaders-kahoot-app-case-study|p:|',
#       's:https|h:com|h:twitter|p:getkahoot|',
#       's:https|h:com|h:kahoot|p:what-is-kahoot|p:|',
#       's:https|h:com|h:kahoot|p:jobs|p:|',
#       's:https|h:com|h:kahoot|p:blog|p:tag|p:case-studies|p:|',
#       's:https|h:com|h:kahoot|p:terms-and-conditions|p:|',
#       's:https|h:com|h:kahoot|p:businesses|p:use-cases|p:|',
#       's:https|h:com|h:kahoot|p:businesses|p:pricing|p:|',
#       's:https|h:com|h:kahoot|p:blog|p:author|p:kahootkrew|p:|',
#       's:https|h:com|h:kahoot|',
#       's:http|h:com|h:linkedin|h:www|p:shareArticle|q:mini=true&url=https%3A%2F%2Fkahoot.com%2Fblog%2F2017%2F12%2F05%2Fgetty-images-case-study-kahoot%2F&title=Getty%20Images%3A%20%E2%80%9CKahoot%21%20is%20built%20into%20our%20organizational%20culture%E2%80%9D&summary=Sales%20training%2C%20management%20meetings%2C%20presentations%2C%20events%20with%20Kahoot%21%20%E2%80%93%20learn%20how%20Getty%20Images%20weaved%20game-based%20learning%20into%20their%20organizational%20culture.&source=https%3A%2F%2Fwww.kahoot.com|',
#       's:https|h:com|h:kahoot|p:resources|p:|',
#       's:https|h:com|h:kahoot|p:partners|p:|',
#       's:https|h:com|h:kahoot|p:library|p:|',
#       's:https|h:com|h:kahoot|p:blog|p:2018|p:09|p:20|p:mastering-internet-basics-with-kahoot|p:|',
#       's:https|h:com|h:kahoot|p:help|p:|',
#       's:https|h:com|h:twitter|p:share|q:text=Getty%20Images%3A%20%E2%80%9CKahoot%21%20is%20built%20into%20our%20organizational%20culture%E2%80%9D&url=https%3A%2F%2Fkahoot.com%2Fblog%2F2017%2F12%2F05%2Fgetty-images-case-study-kahoot%2F&via=getkahoot|',
#       's:https|h:it|h:kahoot|h:create|',
#       's:https|h:com|h:facebook|h:www|p:getkahoot|',
#       's:https|h:com|h:kahoot|p:privacy-policy|p:|',
#       's:https|h:com|h:kahoot|p:businesses|p:pro|p:|',
#       's:https|h:com|h:kahoot|p:privacy-policy|p:|f:using-cookies|',
#       's:https|h:com|h:kahoot|p:blog|p:2017|p:12|p:05|p:getty-images-case-study-kahoot|p:|f:top|',
#       's:https|h:com|h:kahoot|p:accessibility-policy|p:|',
#       's:https|h:com|h:instagram|h:www|p:getkahoot|p:|',
#       's:https|h:com|h:linkedin|h:www|p:company-beta|p:3324893|p:|q:pathWildcard=3324893|',
#       's:https|h:com|h:kahoot|p:leadership|p:|',
#       's:https|h:it|h:kahoot|h:create|p:register|',
#       's:https|h:com|h:kahoot|p:company|p:|',
#       's:https|h:com|h:kahoot|p:blog|p:tag|p:pedagogy|p:|',
#       's:https|h:com|h:kahoot|p:mobile-app|p:|'],
#      'lru': 's:https|h:com|h:kahoot|p:blog|p:2017|p:12|p:05|p:getty-images-case-study-kahoot|p:|',
#      'content_type': 'text/html',
#      'error': None,
#      '_job': 'a04b5cc0cc6d11e8a0b00242ac120003',
#      'type': 'page',
#      'size': 57259}}]}}

# %%
# EXAMPLE QUERY 3: List web entities containing a given expression
search_query = "funny"
es.search(
    index=settings['es_index'],
    body={
        "query": {
            "bool": {
              "must": [
                { "match": { "type": "page" } },
                { "match": { "text": search_query } }
              ]
            }
        },
        "size": 0,
        "aggs": {
            "group_by_webentity": {
                "terms": {
                    "field": "webentity"
                }
            }
        }
    }
)
# Out:
# {'took': 2,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 5, 'max_score': 0.0, 'hits': []},
#  'aggregations': {'group_by_webentity': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': 14, 'doc_count': 1},
#     {'key': 99, 'doc_count': 1},
#     {'key': 129, 'doc_count': 1},
#     {'key': 158, 'doc_count': 1},
#     {'key': 205, 'doc_count': 1}]}}}

# %%
# FUNCTIONS

# Count how many web entities contain a list of different expressions.
# Note: only counts when those expressions appear in the same page(s).
def count_webentities_containing(expressions):
    result = es.search(
        index=settings['es_index'],
        body={
            "query": {
                "bool": {
                  "must": [{ "match": { "type": "page" } }] + [{ "match": { "text": e } } for e in expressions]
                }
            },
            "size": 0,
            "aggs": {
                "group_by_webentity": {
                    "terms": {
                        "field": "webentity"
                    }
                }
            }
        }
    )
    return len(result['aggregations']['group_by_webentity']['buckets'])

# Usage:
# count_webentities_containing(['funny'])

# Count how many web entities contain a list of different list of alternative expressions.
# Note: only counts when those expressions appear in the same page(s).
def count_webentities_containing_alt(alt_expressions):
    result = es.search(
        index=settings['es_index'],
        body={
            "query": {
                "bool": {
                  "must": [{ "match": { "type": "page" } }] + [{"bool": {"should": [{ "match": { "text": e } } for e in expressions]}} for expressions in alt_expressions]
                }
            },
            "size": 0,
            "aggs": {
                "group_by_webentity": {
                    "terms": {
                        "field": "webentity"
                    }
                }
            }
        }
    )
    return len(result['aggregations']['group_by_webentity']['buckets'])

# Usage:
# count_webentities_containing_alt([['happy', 'merry'], ['christmas', 'xmas']])

# %%
es.search(
        index=settings['es_index'],
        body={
            "query": {
                "bool": {
                  "must": [
                      { "match": { "type": "page" } },
                      {
                          "bool": {
                              "should": [
                                  { "match": { "text": "funny" }},
                                  { "match": { "text": "sad" }}
                              ]
                          }
                      }
                  ]
                }
            },
            "size": 0,
            "aggs": {
                "group_by_webentity": {
                    "terms": {
                        "field": "webentity"
                    }
                }
            }
        }
    )
# Out:
# {'took': 6,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 18, 'max_score': 0.0, 'hits': []},
#  'aggregations': {'group_by_webentity': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 3,
#    'buckets': [{'key': 44, 'doc_count': 3},
#     {'key': 156, 'doc_count': 3},
#     {'key': 55, 'doc_count': 2},
#     {'key': 14, 'doc_count': 1},
#     {'key': 58, 'doc_count': 1},
#     {'key': 59, 'doc_count': 1},
#     {'key': 60, 'doc_count': 1},
#     {'key': 67, 'doc_count': 1},
#     {'key': 99, 'doc_count': 1},
#     {'key': 107, 'doc_count': 1}]}}}
